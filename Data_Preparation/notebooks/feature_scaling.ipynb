# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('../data/processed/Dataset_ATS_v2_cleaned_encoded.csv')
df
# Out:
#       customer_id  SeniorCitizen  Dependents  tenure  PhoneService  \
# 0               1              0           0       1             0
# 1               2              0           0      41             1
# 2               3              0           1      52             1
# 3               4              0           0       1             1
# 4               5              0           0      67             1
# ...           ...            ...         ...     ...           ...
# 7038         7039              0           0       1             1
# 7039         7040              0           1      23             1
# 7040         7041              0           1      12             1
# 7041         7042              1           0      12             1
# 7042         7043              0           0      26             1
#
#       MultipleLines  MonthlyCharges  Churn  gender_Female  gender_Male  \
# 0                 0              25      1              1            0
# ...

# %%
scale_cols = ['MonthlyCharges', 'tenure']
scaler = MinMaxScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])
df
# Out:
#       customer_id  SeniorCitizen  Dependents    tenure  PhoneService  \
# 0               1              0           0  0.013889             0
# 1               2              0           0  0.569444             1
# 2               3              0           1  0.722222             1
# 3               4              0           0  0.013889             1
# 4               5              0           0  0.930556             1
# ...           ...            ...         ...       ...           ...
# 7038         7039              0           0  0.013889             1
# 7039         7040              0           1  0.319444             1
# 7040         7041              0           1  0.166667             1
# 7041         7042              1           0  0.166667             1
# 7042         7043              0           0  0.361111             1
#
#       MultipleLines  MonthlyCharges  Churn  gender_Female  gender_Male  \
# ...

# %%
df.to_csv('../data/processed/Dataset_ATS_v2_processed.csv')
